# %%
print("Muhamamd shahnawaz")
# Out:
# Muhamamd shahnawaz

# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create an array
arr = np.array([1, 2, 3, 4])
print("Array:", arr)

# Array of zeros
zeros = np.zeros((2, 3))
print("\nZeros Array:\n", zeros)

# Random numbers
random_arr = np.random.rand(4, 4)
print("\nRandom Array:\n", random_arr)

# Basic stats
print("\nSum:", arr.sum())
print("Mean:", arr.mean())
# Out:
# Array: [1 2 3 4]
#
# Zeros Array:
#  [[0. 0. 0.]
#  [0. 0. 0.]]
#
# Random Array:
#  [[0.35338341 0.76295206 0.17217271 0.30858547]
#  [0.90329647 0.19438005 0.80879631 0.51959607]
#  [0.55045699 0.08390642 0.11895474 0.24892812]
#  [0.7870945  0.60306402 0.58523591 0.85244458]]
#
# Sum: 10
# Mean: 2.5

# %%
# Create a DataFrame
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "Paris", "London"]
}
df = pd.DataFrame(data)
print(df)

# Read CSV (example, no real file)
# df = pd.read_csv("your_file.csv")

# Data Summary
print("\nInfo:")
print(df.info())

print("\nDescribe:")
print(df.describe())

# Filtering
print("\nFilter Age > 25:")
print(df[df['Age'] > 25])
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None
#
# Describe:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0
#
# Filter Age > 25:
#       Name  Age    City
# 1      Bob   30   Paris
# 2  Charlie   35  London

# %%
# Basic line plot
x = [0, 1, 2, 3]
y = [0, 1, 4, 9]

plt.plot(x, y)
plt.title("Line Plot Example")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(True)
plt.show()

# Scatter plot
plt.scatter(x, y, color='red')
plt.title("Scatter Plot Example")
plt.show()

# %%
# Basic line plot
x = [0, 1, 2, 3]
y = [0, 1, 4, 9]

plt.plot(x, y)
plt.title("Line Plot Example")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(True)
plt.show()

# Scatter plot
plt.scatter(x, y, color='red')
plt.title("Scatter Plot Example")
plt.show()

# %%
# Load the sample dataset
tips = sns.load_dataset("tips")

# Basic scatter plot
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Bill vs Tip")
plt.show()

# Box plot
sns.boxplot(x="day", y="total_bill", data=tips)
plt.title("Boxplot: Total Bill by Day")
plt.show()

# Heatmap (correlation) -- FIXED PART
# Select only numeric columns before correlation
numeric_tips = tips.select_dtypes(include='number')
corr = numeric_tips.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
